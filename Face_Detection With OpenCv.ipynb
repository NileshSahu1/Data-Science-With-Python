# %%
import cv2

# %%
face_cascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
#extensible markup language

# %%
# Reading the image as it is
img = cv2.imread("download (1).jpg")
# Reading the image as gray scale image
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# Search the co-ordintes of the image
faces = face_cascade.detectMultiScale(gray_img, scaleFactor = 1.05,
                                      minNeighbors=5)
for x,y,w,h in faces:
    img = cv2.rectangle(img, (x,y), (x+w,y+h),(0,255,0),3)       # dynamic not static
resized = cv2.resize(img, (int(img.shape[1]/7),int(img.shape[0]/7)))
cv2.imshow("Gray", resized)
cv2.waitKey(2000)         # 2000ms, 0 on key
cv2.destroyAllWindows()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(gray_img,cmap='gray')

# %%
print("Number of Faces:" ,len(faces))
# Out:
# Number of Faces: 1

# %%
def convertToRGB(image):
    return cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(convertToRGB(img))

# %%
def detect_faces(face_cascade, img, scaleFactor = 1.1):
    # create a copy of the image to prevent any changes to the original one.
    image_copy = test_image.copy()
    
    #convert the test image to gray scale as opencv face detector expects gray images
    gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)
    
    # Applying the haar classifier to detect faces
    faces_rect = face_cascade.detectMultiScale(gray_image, scaleFactor=scaleFactor, minNeighbors=5)
    
    for (x, y, w, h) in faces_rect:
        cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)
        
    return image_copy

# %%
test_image=cv2.imread('group.jpg')

# %%
plt.imshow(test_image)

# %%
faces=detect_faces(face_cascade , test_image)

# %%
plt.imshow(convertToRGB(faces))
